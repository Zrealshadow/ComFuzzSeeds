# %%
# -*- coding: utf-8 -*-
# @author: lingze
# @time: 2024/11/13

# %%

import json
import configparser
import sqlalchemy
from sqlalchemy import create_engine, URL
from sqlalchemy.exc import SQLAlchemyError

# %%
# connect to postgresql database
config = configparser.ConfigParser()
config.read('./db.ini')
db_config = dict(config.items('database'))

url_obj = URL.create(
    "postgresql+psycopg2",
    username=db_config['user'],
    password=db_config['password'],
    host=db_config['host'],
    port=db_config['port'],
    database=db_config['database'],
)
print(url_obj)
# statement timeout 10_000 ms
args={"options": "-c statement_timeout=10000"}
engine = create_engine(url_obj, connect_args=args)
# Out:
# postgresql+psycopg2://lingze:***@sbip-g2.d2.comp.nus.edu.sg:6667/fuzz

# %%
# read the sqls files
path = './tmp/clean_sqls/correct_sqls.json'
with open(path, 'r', encoding='utf-8') as f:
    sqls = json.load(f)
    print(f"The number of correct sqls is {len(sqls)}")

path = './tmp/clean_sqls/fixed_flaw_sqls.json'
with open(path, 'r', encoding='utf-8') as f:
    tmp_sqls = json.load(f)
    print(f"The number of fixed flaw sqls is {len(tmp_sqls)}")
    sqls.update(tmp_sqls)
# Out:
# The number of correct sqls is 2753
# The number of fixed flaw sqls is 340

# %%
seed_sql_snippets = []
cnt = 0
n = len(sqls)
with engine.connect() as conn:
    for _, sql_snippet in sqls.items():
        try:
            with conn.begin() as trans:
                    conn.execute(sqlalchemy.text(sql_snippet))
                # Rollback the transaction to prevent changes
            trans.rollback()
            seed_sql_snippets.append(sql_snippet)
            print(f"Progress {cnt} / {n} - effective seed {len(seed_sql_snippets)} - SQL snippet can be executed independently")
        except SQLAlchemyError as e:
            print(f"Progress {cnt} / {n} - effective seed {len(seed_sql_snippets)} -SQL snippet can not be executed independently")
        
        cnt += 1
# Out:
# Progress 0 / 3093 - effective seed 0 -SQL snippet can not be executed independently
# Progress 1 / 3093 - effective seed 0 -SQL snippet can not be executed independently
# Progress 2 / 3093 - effective seed 0 -SQL snippet can not be executed independently
# Progress 3 / 3093 - effective seed 0 -SQL snippet can not be executed independently
# Progress 4 / 3093 - effective seed 0 -SQL snippet can not be executed independently
# Progress 5 / 3093 - effective seed 0 -SQL snippet can not be executed independently
# Progress 6 / 3093 - effective seed 0 -SQL snippet can not be executed independently
# Progress 7 / 3093 - effective seed 0 -SQL snippet can not be executed independently
# Progress 8 / 3093 - effective seed 0 -SQL snippet can not be executed independently
# Progress 9 / 3093 - effective seed 0 -SQL snippet can not be executed independently
# Progress 10 / 3093 - effective seed 0 -SQL snippet can not be executed independently
# Progress 11 / 3093 - effective seed 0 -SQL snippet can not be executed independently
# Progress 12 / 3093 - effective seed 0 -SQL snippet can not be executed independently
# Progress 13 / 3093 - effective seed 0 -SQL snippet can not be executed independently
# <ipython-input-4-0411f81d1580>:12: SAWarning: transaction already deassociated from connection
#   trans.rollback()
# Progress 14 / 3093 - effective seed 1 - SQL snippet can be executed independently
# Progress 15 / 3093 - effective seed 2 - SQL snippet can be executed independently
# Progress 16 / 3093 - effective seed 2 -SQL snippet can not be executed independently
# Progress 17 / 3093 - effective seed 2 -SQL snippet can not be executed independently
# Progress 18 / 3093 - effective seed 3 - SQL snippet can be executed independently
# Progress 19 / 3093 - effective seed 3 -SQL snippet can not be executed independently
# Progress 20 / 3093 - effective seed 3 -SQL snippet can not be executed independently
# Progress 21 / 3093 - effective seed 3 -SQL snippet can not be executed independently
# Progress 22 / 3093 - effective seed 3 -SQL snippet can not be executed independently
# Progress 23 / 3093 - effective seed 3 -SQL snippet can not be executed independently
# Progress 24 / 3093 - effective seed 3 -SQL snippet can not be executed independently
# Progress 25 / 3093 - effective seed 3 -SQL snippet can not be executed independently
# Progress 26 / 3093 - effective seed 3 -SQL snippet can not be executed independently
# Progress 27 / 3093 - effective seed 3 -SQL snippet can not be executed independently
# Progress 28 / 3093 - effective seed 3 -SQL snippet can not be executed independently
# Progress 29 / 3093 - effective seed 3 -SQL snippet can not be executed independently
# Progress 30 / 3093 - effective seed 3 -SQL snippet can not be executed independently
# Progress 31 / 3093 - effective seed 3 -SQL snippet can not be executed independently
# Progress 32 / 3093 - effective seed 3 -SQL snippet can not be executed independently
# Progress 33 / 3093 - effective seed 3 -SQL snippet can not be executed independently
# Progress 34 / 3093 - effective seed 3 -SQL snippet can not be executed independently
# Progress 35 / 3093 - effective seed 3 -SQL snippet can not be executed independently
# Progress 36 / 3093 - effective seed 3 -SQL snippet can not be executed independently
# Progress 37 / 3093 - effective seed 4 - SQL snippet can be executed independently
# Progress 38 / 3093 - effective seed 4 -SQL snippet can not be executed independently
# Progress 39 / 3093 - effective seed 4 -SQL snippet can not be executed independently
# Progress 40 / 3093 - effective seed 4 -SQL snippet can not be executed independently
# Progress 41 / 3093 - effective seed 4 -SQL snippet can not be executed independently
# Progress 42 / 3093 - effective seed 4 -SQL snippet can not be executed independently
# Progress 43 / 3093 - effective seed 5 - SQL snippet can be executed independently
# Progress 44 / 3093 - effective seed 5 -SQL snippet can not be executed independently
# Progress 45 / 3093 - effective seed 6 - SQL snippet can be executed independently
# Progress 46 / 3093 - effective seed 6 -SQL snippet can not be executed independently
# Progress 47 / 3093 - effective seed 6 -SQL snippet can not be executed independently
# Progress 48 / 3093 - effective seed 6 -SQL snippet can not be executed independently
# Progress 49 / 3093 - effective seed 6 -SQL snippet can not be executed independently
# Progress 50 / 3093 - effective seed 6 -SQL snippet can not be executed independently
# Progress 51 / 3093 - effective seed 6 -SQL snippet can not be executed independently
# Progress 52 / 3093 - effective seed 6 -SQL snippet can not be executed independently
# Progress 53 / 3093 - effective seed 6 -SQL snippet can not be executed independently
# Progress 54 / 3093 - effective seed 7 - SQL snippet can be executed independently
# Progress 55 / 3093 - effective seed 7 -SQL snippet can not be executed independently
# Progress 56 / 3093 - effective seed 7 -SQL snippet can not be executed independently
# Progress 57 / 3093 - effective seed 7 -SQL snippet can not be executed independently
# Progress 58 / 3093 - effective seed 7 -SQL snippet can not be executed independently
# Progress 59 / 3093 - effective seed 7 -SQL snippet can not be executed independently
# Progress 60 / 3093 - effective seed 8 - SQL snippet can be executed independently
# Progress 61 / 3093 - effective seed 8 -SQL snippet can not be executed independently
# Progress 62 / 3093 - effective seed 8 -SQL snippet can not be executed independently
# Progress 63 / 3093 - effective seed 8 -SQL snippet can not be executed independently
# Progress 64 / 3093 - effective seed 9 - SQL snippet can be executed independently
# Progress 65 / 3093 - effective seed 9 -SQL snippet can not be executed independently
# Progress 66 / 3093 - effective seed 9 -SQL snippet can not be executed independently
# Progress 67 / 3093 - effective seed 9 -SQL snippet can not be executed independently
# Progress 68 / 3093 - effective seed 9 -SQL snippet can not be executed independently
# Progress 69 / 3093 - effective seed 9 -SQL snippet can not be executed independently
# Progress 70 / 3093 - effective seed 10 - SQL snippet can be executed independently
# Progress 71 / 3093 - effective seed 10 -SQL snippet can not be executed independently
# Progress 72 / 3093 - effective seed 10 -SQL snippet can not be executed independently
# Progress 73 / 3093 - effective seed 11 - SQL snippet can be executed independently
# Progress 74 / 3093 - effective seed 12 - SQL snippet can be executed independently
# Progress 75 / 3093 - effective seed 13 - SQL snippet can be executed independently
# Progress 76 / 3093 - effective seed 13 -SQL snippet can not be executed independently
# Progress 77 / 3093 - effective seed 13 -SQL snippet can not be executed independently
# Progress 78 / 3093 - effective seed 13 -SQL snippet can not be executed independently
# Progress 79 / 3093 - effective seed 13 -SQL snippet can not be executed independently
# Progress 80 / 3093 - effective seed 13 -SQL snippet can not be executed independently
# Progress 81 / 3093 - effective seed 13 -SQL snippet can not be executed independently
# Progress 82 / 3093 - effective seed 14 - SQL snippet can be executed independently
# Progress 83 / 3093 - effective seed 14 -SQL snippet can not be executed independently
# Progress 84 / 3093 - effective seed 14 -SQL snippet can not be executed independently
# Progress 85 / 3093 - effective seed 15 - SQL snippet can be executed independently
# Progress 86 / 3093 - effective seed 15 -SQL snippet can not be executed independently
# Progress 87 / 3093 - effective seed 15 -SQL snippet can not be executed independently
# Progress 88 / 3093 - effective seed 15 -SQL snippet can not be executed independently
# Progress 89 / 3093 - effective seed 15 -SQL snippet can not be executed independently
# Progress 90 / 3093 - effective seed 15 -SQL snippet can not be executed independently
# Progress 91 / 3093 - effective seed 15 -SQL snippet can not be executed independently
# Progress 92 / 3093 - effective seed 15 -SQL snippet can not be executed independently
# Progress 93 / 3093 - effective seed 16 - SQL snippet can be executed independently
# Progress 94 / 3093 - effective seed 16 -SQL snippet can not be executed independently
# Progress 95 / 3093 - effective seed 16 -SQL snippet can not be executed independently
# Progress 96 / 3093 - effective seed 16 -SQL snippet can not be executed independently
# Progress 97 / 3093 - effective seed 16 -SQL snippet can not be executed independently
# Progress 98 / 3093 - effective seed 16 -SQL snippet can not be executed independently
# Progress 99 / 3093 - effective seed 16 -SQL snippet can not be executed independently
# Progress 100 / 3093 - effective seed 16 -SQL snippet can not be executed independently
# Progress 101 / 3093 - effective seed 16 -SQL snippet can not be executed independently
# Progress 102 / 3093 - effective seed 16 -SQL snippet can not be executed independently
# Progress 103 / 3093 - effective seed 16 -SQL snippet can not be executed independently
# Progress 104 / 3093 - effective seed 17 - SQL snippet can be executed independently
# Progress 105 / 3093 - effective seed 17 -SQL snippet can not be executed independently
# Progress 106 / 3093 - effective seed 17 -SQL snippet can not be executed independently
# Progress 107 / 3093 - effective seed 17 -SQL snippet can not be executed independently
# Progress 108 / 3093 - effective seed 17 -SQL snippet can not be executed independently
# Progress 109 / 3093 - effective seed 17 -SQL snippet can not be executed independently
# Progress 110 / 3093 - effective seed 17 -SQL snippet can not be executed independently
# Progress 111 / 3093 - effective seed 17 -SQL snippet can not be executed independently
# Progress 112 / 3093 - effective seed 17 -SQL snippet can not be executed independently
# Progress 113 / 3093 - effective seed 18 - SQL snippet can be executed independently
# Progress 114 / 3093 - effective seed 18 -SQL snippet can not be executed independently
# Progress 115 / 3093 - effective seed 18 -SQL snippet can not be executed independently
# Progress 116 / 3093 - effective seed 18 -SQL snippet can not be executed independently
# Progress 117 / 3093 - effective seed 18 -SQL snippet can not be executed independently
# Progress 118 / 3093 - effective seed 18 -SQL snippet can not be executed independently
# Progress 119 / 3093 - effective seed 18 -SQL snippet can not be executed independently
# Progress 120 / 3093 - effective seed 18 -SQL snippet can not be executed independently
# Progress 121 / 3093 - effective seed 18 -SQL snippet can not be executed independently
# Progress 122 / 3093 - effective seed 18 -SQL snippet can not be executed independently
# Progress 123 / 3093 - effective seed 18 -SQL snippet can not be executed independently
# Progress 124 / 3093 - effective seed 19 - SQL snippet can be executed independently
# Progress 125 / 3093 - effective seed 19 -SQL snippet can not be executed independently
# Progress 126 / 3093 - effective seed 19 -SQL snippet can not be executed independently
# Progress 127 / 3093 - effective seed 19 -SQL snippet can not be executed independently
# Progress 128 / 3093 - effective seed 19 -SQL snippet can not be executed independently
# Progress 129 / 3093 - effective seed 19 -SQL snippet can not be executed independently
# Progress 130 / 3093 - effective seed 19 -SQL snippet can not be executed independently
# Progress 131 / 3093 - effective seed 19 -SQL snippet can not be executed independently
# Progress 132 / 3093 - effective seed 19 -SQL snippet can not be executed independently
# Progress 133 / 3093 - effective seed 19 -SQL snippet can not be executed independently
# Progress 134 / 3093 - effective seed 19 -SQL snippet can not be executed independently
# Progress 135 / 3093 - effective seed 20 - SQL snippet can be executed independently
# Progress 136 / 3093 - effective seed 20 -SQL snippet can not be executed independently
# Progress 137 / 3093 - effective seed 21 - SQL snippet can be executed independently
# Progress 138 / 3093 - effective seed 21 -SQL snippet can not be executed independently
# Progress 139 / 3093 - effective seed 22 - SQL snippet can be executed independently
# Progress 140 / 3093 - effective seed 23 - SQL snippet can be executed independently
# Progress 141 / 3093 - effective seed 23 -SQL snippet can not be executed independently
# Progress 142 / 3093 - effective seed 23 -SQL snippet can not be executed independently
# Progress 143 / 3093 - effective seed 23 -SQL snippet can not be executed independently
# Progress 144 / 3093 - effective seed 23 -SQL snippet can not be executed independently
# Progress 145 / 3093 - effective seed 23 -SQL snippet can not be executed independently
# Progress 146 / 3093 - effective seed 24 - SQL snippet can be executed independently
# Progress 147 / 3093 - effective seed 24 -SQL snippet can not be executed independently
# Progress 148 / 3093 - effective seed 24 -SQL snippet can not be executed independently
# Progress 149 / 3093 - effective seed 24 -SQL snippet can not be executed independently
# Progress 150 / 3093 - effective seed 25 - SQL snippet can be executed independently
# Progress 151 / 3093 - effective seed 25 -SQL snippet can not be executed independently
# Progress 152 / 3093 - effective seed 25 -SQL snippet can not be executed independently
# Progress 153 / 3093 - effective seed 25 -SQL snippet can not be executed independently
# Progress 154 / 3093 - effective seed 25 -SQL snippet can not be executed independently
# Progress 155 / 3093 - effective seed 25 -SQL snippet can not be executed independently
# Progress 156 / 3093 - effective seed 25 -SQL snippet can not be executed independently
# Progress 157 / 3093 - effective seed 25 -SQL snippet can not be executed independently
# Progress 158 / 3093 - effective seed 25 -SQL snippet can not be executed independently
# Progress 159 / 3093 - effective seed 25 -SQL snippet can not be executed independently
# Progress 160 / 3093 - effective seed 26 - SQL snippet can be executed independently
# Progress 161 / 3093 - effective seed 26 -SQL snippet can not be executed independently
# Progress 162 / 3093 - effective seed 26 -SQL snippet can not be executed independently
# Progress 163 / 3093 - effective seed 26 -SQL snippet can not be executed independently
# Progress 164 / 3093 - effective seed 26 -SQL snippet can not be executed independently
# Progress 165 / 3093 - effective seed 26 -SQL snippet can not be executed independently
# Progress 166 / 3093 - effective seed 26 -SQL snippet can not be executed independently
# Progress 167 / 3093 - effective seed 26 -SQL snippet can not be executed independently
# Progress 168 / 3093 - effective seed 26 -SQL snippet can not be executed independently
# Progress 169 / 3093 - effective seed 27 - SQL snippet can be executed independently
# Progress 170 / 3093 - effective seed 27 -SQL snippet can not be executed independently
# Progress 171 / 3093 - effective seed 27 -SQL snippet can not be executed independently
# Progress 172 / 3093 - effective seed 27 -SQL snippet can not be executed independently
# Progress 173 / 3093 - effective seed 27 -SQL snippet can not be executed independently
# Progress 174 / 3093 - effective seed 27 -SQL snippet can not be executed independently
# Progress 175 / 3093 - effective seed 27 -SQL snippet can not be executed independently
# Progress 176 / 3093 - effective seed 28 - SQL snippet can be executed independently
# Progress 177 / 3093 - effective seed 29 - SQL snippet can be executed independently
# Progress 178 / 3093 - effective seed 30 - SQL snippet can be executed independently
# Progress 179 / 3093 - effective seed 30 -SQL snippet can not be executed independently
# Progress 180 / 3093 - effective seed 30 -SQL snippet can not be executed independently
# Progress 181 / 3093 - effective seed 30 -SQL snippet can not be executed independently
# Progress 182 / 3093 - effective seed 30 -SQL snippet can not be executed independently
# Progress 183 / 3093 - effective seed 30 -SQL snippet can not be executed independently
# Progress 184 / 3093 - effective seed 31 - SQL snippet can be executed independently
# Progress 185 / 3093 - effective seed 31 -SQL snippet can not be executed independently
# Progress 186 / 3093 - effective seed 31 -SQL snippet can not be executed independently
# Progress 187 / 3093 - effective seed 31 -SQL snippet can not be executed independently
# Progress 188 / 3093 - effective seed 31 -SQL snippet can not be executed independently
# Progress 189 / 3093 - effective seed 31 -SQL snippet can not be executed independently
# Progress 190 / 3093 - effective seed 31 -SQL snippet can not be executed independently
# Progress 191 / 3093 - effective seed 32 - SQL snippet can be executed independently
# Progress 192 / 3093 - effective seed 32 -SQL snippet can not be executed independently
# Progress 193 / 3093 - effective seed 32 -SQL snippet can not be executed independently
# Progress 194 / 3093 - effective seed 32 -SQL snippet can not be executed independently
# Progress 195 / 3093 - effective seed 32 -SQL snippet can not be executed independently
# Progress 196 / 3093 - effective seed 32 -SQL snippet can not be executed independently
# Progress 197 / 3093 - effective seed 32 -SQL snippet can not be executed independently
# Progress 198 / 3093 - effective seed 32 -SQL snippet can not be executed independently
# Progress 199 / 3093 - effective seed 32 -SQL snippet can not be executed independently
# Progress 200 / 3093 - effective seed 32 -SQL snippet can not be executed independently
# Progress 201 / 3093 - effective seed 32 -SQL snippet can not be executed independently
# Progress 202 / 3093 - effective seed 32 -SQL snippet can not be executed independently
# Progress 203 / 3093 - effective seed 33 - SQL snippet can be executed independently
# Progress 204 / 3093 - effective seed 33 -SQL snippet can not be executed independently
# Progress 205 / 3093 - effective seed 33 -SQL snippet can not be executed independently
# Progress 206 / 3093 - effective seed 33 -SQL snippet can not be executed independently
# Progress 207 / 3093 - effective seed 33 -SQL snippet can not be executed independently
# Progress 208 / 3093 - effective seed 33 -SQL snippet can not be executed independently
# Progress 209 / 3093 - effective seed 33 -SQL snippet can not be executed independently
# Progress 210 / 3093 - effective seed 33 -SQL snippet can not be executed independently
# Progress 211 / 3093 - effective seed 33 -SQL snippet can not be executed independently
# Progress 212 / 3093 - effective seed 33 -SQL snippet can not be executed independently
# Progress 213 / 3093 - effective seed 33 -SQL snippet can not be executed independently
# Progress 214 / 3093 - effective seed 33 -SQL snippet can not be executed independently
# Progress 215 / 3093 - effective seed 33 -SQL snippet can not be executed independently
# Progress 216 / 3093 - effective seed 33 -SQL snippet can not be executed independently
# Progress 217 / 3093 - effective seed 33 -SQL snippet can not be executed independently
# Progress 218 / 3093 - effective seed 34 - SQL snippet can be executed independently
# Progress 219 / 3093 - effective seed 34 -SQL snippet can not be executed independently
# Progress 220 / 3093 - effective seed 35 - SQL snippet can be executed independently
# Progress 221 / 3093 - effective seed 36 - SQL snippet can be executed independently
# Progress 222 / 3093 - effective seed 36 -SQL snippet can not be executed independently
# Progress 223 / 3093 - effective seed 37 - SQL snippet can be executed independently
# Progress 224 / 3093 - effective seed 37 -SQL snippet can not be executed independently
# Progress 225 / 3093 - effective seed 37 -SQL snippet can not be executed independently
# Progress 226 / 3093 - effective seed 37 -SQL snippet can not be executed independently
# Progress 227 / 3093 - effective seed 37 -SQL snippet can not be executed independently
# Progress 228 / 3093 - effective seed 37 -SQL snippet can not be executed independently
# Progress 229 / 3093 - effective seed 37 -SQL snippet can not be executed independently
# Progress 230 / 3093 - effective seed 37 -SQL snippet can not be executed independently
# Progress 231 / 3093 - effective seed 37 -SQL snippet can not be executed independently
# Progress 232 / 3093 - effective seed 37 -SQL snippet can not be executed independently
# Progress 233 / 3093 - effective seed 37 -SQL snippet can not be executed independently
# Progress 234 / 3093 - effective seed 37 -SQL snippet can not be executed independently
# Progress 235 / 3093 - effective seed 37 -SQL snippet can not be executed independently
# Progress 236 / 3093 - effective seed 37 -SQL snippet can not be executed independently
# Progress 237 / 3093 - effective seed 37 -SQL snippet can not be executed independently
# Progress 238 / 3093 - effective seed 37 -SQL snippet can not be executed independently
# Progress 239 / 3093 - effective seed 37 -SQL snippet can not be executed independently
# Progress 240 / 3093 - effective seed 37 -SQL snippet can not be executed independently
# Progress 241 / 3093 - effective seed 37 -SQL snippet can not be executed independently
# Progress 242 / 3093 - effective seed 37 -SQL snippet can not be executed independently
# Progress 243 / 3093 - effective seed 37 -SQL snippet can not be executed independently
# Progress 244 / 3093 - effective seed 38 - SQL snippet can be executed independently
# Progress 245 / 3093 - effective seed 38 -SQL snippet can not be executed independently
# Progress 246 / 3093 - effective seed 38 -SQL snippet can not be executed independently
# Progress 247 / 3093 - effective seed 38 -SQL snippet can not be executed independently
# Progress 248 / 3093 - effective seed 38 -SQL snippet can not be executed independently
# Progress 249 / 3093 - effective seed 38 -SQL snippet can not be executed independently
# Progress 250 / 3093 - effective seed 38 -SQL snippet can not be executed independently
# Progress 251 / 3093 - effective seed 38 -SQL snippet can not be executed independently
# Progress 252 / 3093 - effective seed 38 -SQL snippet can not be executed independently
# Progress 253 / 3093 - effective seed 38 -SQL snippet can not be executed independently
# Progress 254 / 3093 - effective seed 39 - SQL snippet can be executed independently
# Progress 255 / 3093 - effective seed 39 -SQL snippet can not be executed independently
# Progress 256 / 3093 - effective seed 39 -SQL snippet can not be executed independently
# Progress 257 / 3093 - effective seed 40 - SQL snippet can be executed independently
# Progress 258 / 3093 - effective seed 40 -SQL snippet can not be executed independently
# Progress 259 / 3093 - effective seed 40 -SQL snippet can not be executed independently
# Progress 260 / 3093 - effective seed 40 -SQL snippet can not be executed independently
# Progress 261 / 3093 - effective seed 40 -SQL snippet can not be executed independently
# Progress 262 / 3093 - effective seed 40 -SQL snippet can not be executed independently
# Progress 263 / 3093 - effective seed 41 - SQL snippet can be executed independently
# Progress 264 / 3093 - effective seed 41 -SQL snippet can not be executed independently
# Progress 265 / 3093 - effective seed 42 - SQL snippet can be executed independently
# Progress 266 / 3093 - effective seed 42 -SQL snippet can not be executed independently
# Progress 267 / 3093 - effective seed 42 -SQL snippet can not be executed independently
# Progress 268 / 3093 - effective seed 42 -SQL snippet can not be executed independently
# Progress 269 / 3093 - effective seed 42 -SQL snippet can not be executed independently
# Progress 270 / 3093 - effective seed 42 -SQL snippet can not be executed independently
# Progress 271 / 3093 - effective seed 43 - SQL snippet can be executed independently
# Progress 272 / 3093 - effective seed 43 -SQL snippet can not be executed independently
# Progress 273 / 3093 - effective seed 44 - SQL snippet can be executed independently
# Progress 274 / 3093 - effective seed 44 -SQL snippet can not be executed independently
# Progress 275 / 3093 - effective seed 44 -SQL snippet can not be executed independently
# Progress 276 / 3093 - effective seed 44 -SQL snippet can not be executed independently
# Progress 277 / 3093 - effective seed 44 -SQL snippet can not be executed independently
# Progress 278 / 3093 - effective seed 44 -SQL snippet can not be executed independently
# Progress 279 / 3093 - effective seed 44 -SQL snippet can not be executed independently
# Progress 280 / 3093 - effective seed 44 -SQL snippet can not be executed independently
# Progress 281 / 3093 - effective seed 44 -SQL snippet can not be executed independently
# Progress 282 / 3093 - effective seed 44 -SQL snippet can not be executed independently
# Progress 283 / 3093 - effective seed 44 -SQL snippet can not be executed independently
# Progress 284 / 3093 - effective seed 45 - SQL snippet can be executed independently
# Progress 285 / 3093 - effective seed 45 -SQL snippet can not be executed independently
# Progress 286 / 3093 - effective seed 45 -SQL snippet can not be executed independently
# Progress 287 / 3093 - effective seed 45 -SQL snippet can not be executed independently
# Progress 288 / 3093 - effective seed 45 -SQL snippet can not be executed independently
# Progress 289 / 3093 - effective seed 45 -SQL snippet can not be executed independently
# Progress 290 / 3093 - effective seed 45 -SQL snippet can not be executed independently
# Progress 291 / 3093 - effective seed 46 - SQL snippet can be executed independently
# Progress 292 / 3093 - effective seed 47 - SQL snippet can be executed independently
# Progress 293 / 3093 - effective seed 47 -SQL snippet can not be executed independently
# Progress 294 / 3093 - effective seed 47 -SQL snippet can not be executed independently
# Progress 295 / 3093 - effective seed 47 -SQL snippet can not be executed independently
# Progress 296 / 3093 - effective seed 47 -SQL snippet can not be executed independently
# Progress 297 / 3093 - effective seed 47 -SQL snippet can not be executed independently
# Progress 298 / 3093 - effective seed 47 -SQL snippet can not be executed independently
# Progress 299 / 3093 - effective seed 47 -SQL snippet can not be executed independently
# Progress 300 / 3093 - effective seed 47 -SQL snippet can not be executed independently
# Progress 301 / 3093 - effective seed 47 -SQL snippet can not be executed independently
# Progress 302 / 3093 - effective seed 47 -SQL snippet can not be executed independently
# Progress 303 / 3093 - effective seed 48 - SQL snippet can be executed independently
# Progress 304 / 3093 - effective seed 48 -SQL snippet can not be executed independently
# Progress 305 / 3093 - effective seed 48 -SQL snippet can not be executed independently
# Progress 306 / 3093 - effective seed 49 - SQL snippet can be executed independently
# Progress 307 / 3093 - effective seed 50 - SQL snippet can be executed independently
# Progress 308 / 3093 - effective seed 51 - SQL snippet can be executed independently
# Progress 309 / 3093 - effective seed 51 -SQL snippet can not be executed independently
# Progress 310 / 3093 - effective seed 51 -SQL snippet can not be executed independently
# Progress 311 / 3093 - effective seed 51 -SQL snippet can not be executed independently
# Progress 312 / 3093 - effective seed 52 - SQL snippet can be executed independently
# Progress 313 / 3093 - effective seed 53 - SQL snippet can be executed independently
# Progress 314 / 3093 - effective seed 53 -SQL snippet can not be executed independently
# Progress 315 / 3093 - effective seed 53 -SQL snippet can not be executed independently
# Progress 316 / 3093 - effective seed 53 -SQL snippet can not be executed independently
# Progress 317 / 3093 - effective seed 54 - SQL snippet can be executed independently
# Progress 318 / 3093 - effective seed 54 -SQL snippet can not be executed independently
# Progress 319 / 3093 - effective seed 54 -SQL snippet can not be executed independently
# Progress 320 / 3093 - effective seed 55 - SQL snippet can be executed independently
# Progress 321 / 3093 - effective seed 56 - SQL snippet can be executed independently
# Progress 322 / 3093 - effective seed 56 -SQL snippet can not be executed independently
# Progress 323 / 3093 - effective seed 56 -SQL snippet can not be executed independently
# Progress 324 / 3093 - effective seed 56 -SQL snippet can not be executed independently
# Progress 325 / 3093 - effective seed 57 - SQL snippet can be executed independently
# Progress 326 / 3093 - effective seed 57 -SQL snippet can not be executed independently
# Progress 327 / 3093 - effective seed 57 -SQL snippet can not be executed independently
# Progress 328 / 3093 - effective seed 57 -SQL snippet can not be executed independently
# Progress 329 / 3093 - effective seed 57 -SQL snippet can not be executed independently
# Progress 330 / 3093 - effective seed 57 -SQL snippet can not be executed independently
# Progress 331 / 3093 - effective seed 58 - SQL snippet can be executed independently
# Progress 332 / 3093 - effective seed 59 - SQL snippet can be executed independently
# Progress 333 / 3093 - effective seed 59 -SQL snippet can not be executed independently
# Progress 334 / 3093 - effective seed 59 -SQL snippet can not be executed independently
# Progress 335 / 3093 - effective seed 59 -SQL snippet can not be executed independently
# Progress 336 / 3093 - effective seed 59 -SQL snippet can not be executed independently
# Progress 337 / 3093 - effective seed 59 -SQL snippet can not be executed independently
# Progress 338 / 3093 - effective seed 59 -SQL snippet can not be executed independently
# Progress 339 / 3093 - effective seed 59 -SQL snippet can not be executed independently
# Progress 340 / 3093 - effective seed 59 -SQL snippet can not be executed independently
# Progress 341 / 3093 - effective seed 60 - SQL snippet can be executed independently
# Progress 342 / 3093 - effective seed 61 - SQL snippet can be executed independently
# Progress 343 / 3093 - effective seed 62 - SQL snippet can be executed independently
# Progress 344 / 3093 - effective seed 62 -SQL snippet can not be executed independently
# Progress 345 / 3093 - effective seed 62 -SQL snippet can not be executed independently
# Progress 346 / 3093 - effective seed 62 -SQL snippet can not be executed independently
# Progress 347 / 3093 - effective seed 63 - SQL snippet can be executed independently
# Progress 348 / 3093 - effective seed 63 -SQL snippet can not be executed independently
# Progress 349 / 3093 - effective seed 63 -SQL snippet can not be executed independently
# Progress 350 / 3093 - effective seed 64 - SQL snippet can be executed independently
# Progress 351 / 3093 - effective seed 64 -SQL snippet can not be executed independently
# Progress 352 / 3093 - effective seed 64 -SQL snippet can not be executed independently
# Progress 353 / 3093 - effective seed 64 -SQL snippet can not be executed independently
# Progress 354 / 3093 - effective seed 64 -SQL snippet can not be executed independently
# Progress 355 / 3093 - effective seed 64 -SQL snippet can not be executed independently
# Progress 356 / 3093 - effective seed 64 -SQL snippet can not be executed independently
# Progress 357 / 3093 - effective seed 64 -SQL snippet can not be executed independently
# Progress 358 / 3093 - effective seed 64 -SQL snippet can not be executed independently
# Progress 359 / 3093 - effective seed 65 - SQL snippet can be executed independently
# Progress 360 / 3093 - effective seed 65 -SQL snippet can not be executed independently
# Progress 361 / 3093 - effective seed 66 - SQL snippet can be executed independently
# Progress 362 / 3093 - effective seed 66 -SQL snippet can not be executed independently
# Progress 363 / 3093 - effective seed 66 -SQL snippet can not be executed independently
# Progress 364 / 3093 - effective seed 66 -SQL snippet can not be executed independently
# Progress 365 / 3093 - effective seed 66 -SQL snippet can not be executed independently
# Progress 366 / 3093 - effective seed 67 - SQL snippet can be executed independently
# Progress 367 / 3093 - effective seed 67 -SQL snippet can not be executed independently
# Progress 368 / 3093 - effective seed 67 -SQL snippet can not be executed independently
# Progress 369 / 3093 - effective seed 67 -SQL snippet can not be executed independently
# Progress 370 / 3093 - effective seed 67 -SQL snippet can not be executed independently
# Progress 371 / 3093 - effective seed 67 -SQL snippet can not be executed independently
# Progress 372 / 3093 - effective seed 67 -SQL snippet can not be executed independently
# Progress 373 / 3093 - effective seed 67 -SQL snippet can not be executed independently
# Progress 374 / 3093 - effective seed 67 -SQL snippet can not be executed independently
# Progress 375 / 3093 - effective seed 67 -SQL snippet can not be executed independently
# Progress 376 / 3093 - effective seed 67 -SQL snippet can not be executed independently
# Progress 377 / 3093 - effective seed 68 - SQL snippet can be executed independently
# Progress 378 / 3093 - effective seed 69 - SQL snippet can be executed independently
# Progress 379 / 3093 - effective seed 70 - SQL snippet can be executed independently
# Progress 380 / 3093 - effective seed 70 -SQL snippet can not be executed independently
# Progress 381 / 3093 - effective seed 70 -SQL snippet can not be executed independently
# Progress 382 / 3093 - effective seed 70 -SQL snippet can not be executed independently
# Progress 383 / 3093 - effective seed 70 -SQL snippet can not be executed independently
# Progress 384 / 3093 - effective seed 71 - SQL snippet can be executed independently
# Progress 385 / 3093 - effective seed 71 -SQL snippet can not be executed independently
# Progress 386 / 3093 - effective seed 71 -SQL snippet can not be executed independently
# Progress 387 / 3093 - effective seed 71 -SQL snippet can not be executed independently
# Progress 388 / 3093 - effective seed 72 - SQL snippet can be executed independently
# Progress 389 / 3093 - effective seed 72 -SQL snippet can not be executed independently
# Progress 390 / 3093 - effective seed 72 -SQL snippet can not be executed independently
# Progress 391 / 3093 - effective seed 72 -SQL snippet can not be executed independently
# Progress 392 / 3093 - effective seed 72 -SQL snippet can not be executed independently
# Progress 393 / 3093 - effective seed 72 -SQL snippet can not be executed independently
# Progress 394 / 3093 - effective seed 73 - SQL snippet can be executed independently
# Progress 395 / 3093 - effective seed 73 -SQL snippet can not be executed independently
# Progress 396 / 3093 - effective seed 73 -SQL snippet can not be executed independently
# Progress 397 / 3093 - effective seed 73 -SQL snippet can not be executed independently
# Progress 398 / 3093 - effective seed 74 - SQL snippet can be executed independently
# Progress 399 / 3093 - effective seed 74 -SQL snippet can not be executed independently
# Progress 400 / 3093 - effective seed 75 - SQL snippet can be executed independently
# Progress 401 / 3093 - effective seed 75 -SQL snippet can not be executed independently
# Progress 402 / 3093 - effective seed 76 - SQL snippet can be executed independently
# Progress 403 / 3093 - effective seed 76 -SQL snippet can not be executed independently
# Progress 404 / 3093 - effective seed 76 -SQL snippet can not be executed independently
# Progress 405 / 3093 - effective seed 76 -SQL snippet can not be executed independently
# Progress 406 / 3093 - effective seed 76 -SQL snippet can not be executed independently
# Progress 407 / 3093 - effective seed 77 - SQL snippet can be executed independently
# Progress 408 / 3093 - effective seed 77 -SQL snippet can not be executed independently
# Progress 409 / 3093 - effective seed 78 - SQL snippet can be executed independently
# Progress 410 / 3093 - effective seed 78 -SQL snippet can not be executed independently
# Progress 411 / 3093 - effective seed 79 - SQL snippet can be executed independently
# Progress 412 / 3093 - effective seed 79 -SQL snippet can not be executed independently
# Progress 413 / 3093 - effective seed 79 -SQL snippet can not be executed independently
# Progress 414 / 3093 - effective seed 79 -SQL snippet can not be executed independently
# Progress 415 / 3093 - effective seed 79 -SQL snippet can not be executed independently
# Progress 416 / 3093 - effective seed 79 -SQL snippet can not be executed independently
# Progress 417 / 3093 - effective seed 79 -SQL snippet can not be executed independently
# Progress 418 / 3093 - effective seed 79 -SQL snippet can not be executed independently
# Progress 419 / 3093 - effective seed 79 -SQL snippet can not be executed independently
# Progress 420 / 3093 - effective seed 79 -SQL snippet can not be executed independently
# Progress 421 / 3093 - effective seed 80 - SQL snippet can be executed independently
# Progress 422 / 3093 - effective seed 80 -SQL snippet can not be executed independently
# Progress 423 / 3093 - effective seed 80 -SQL snippet can not be executed independently
# Progress 424 / 3093 - effective seed 80 -SQL snippet can not be executed independently
# Progress 425 / 3093 - effective seed 80 -SQL snippet can not be executed independently
# Progress 426 / 3093 - effective seed 81 - SQL snippet can be executed independently
# Progress 427 / 3093 - effective seed 81 -SQL snippet can not be executed independently
# Progress 428 / 3093 - effective seed 81 -SQL snippet can not be executed independently
# Progress 429 / 3093 - effective seed 82 - SQL snippet can be executed independently
# Progress 430 / 3093 - effective seed 82 -SQL snippet can not be executed independently
# Progress 431 / 3093 - effective seed 82 -SQL snippet can not be executed independently
# Progress 432 / 3093 - effective seed 82 -SQL snippet can not be executed independently
# Progress 433 / 3093 - effective seed 83 - SQL snippet can be executed independently
# Progress 434 / 3093 - effective seed 83 -SQL snippet can not be executed independently
# Progress 435 / 3093 - effective seed 83 -SQL snippet can not be executed independently
# Progress 436 / 3093 - effective seed 83 -SQL snippet can not be executed independently
# Progress 437 / 3093 - effective seed 83 -SQL snippet can not be executed independently
# Progress 438 / 3093 - effective seed 83 -SQL snippet can not be executed independently
# Progress 439 / 3093 - effective seed 84 - SQL snippet can be executed independently
# Progress 440 / 3093 - effective seed 84 -SQL snippet can not be executed independently
# Progress 441 / 3093 - effective seed 85 - SQL snippet can be executed independently
# Progress 442 / 3093 - effective seed 85 -SQL snippet can not be executed independently
# Progress 443 / 3093 - effective seed 85 -SQL snippet can not be executed independently
# Progress 444 / 3093 - effective seed 85 -SQL snippet can not be executed independently
# Progress 445 / 3093 - effective seed 85 -SQL snippet can not be executed independently
# Progress 446 / 3093 - effective seed 86 - SQL snippet can be executed independently
# Progress 447 / 3093 - effective seed 86 -SQL snippet can not be executed independently
# Progress 448 / 3093 - effective seed 86 -SQL snippet can not be executed independently
# Progress 449 / 3093 - effective seed 86 -SQL snippet can not be executed independently
# Progress 450 / 3093 - effective seed 86 -SQL snippet can not be executed independently
# Progress 451 / 3093 - effective seed 86 -SQL snippet can not be executed independently
# Progress 452 / 3093 - effective seed 87 - SQL snippet can be executed independently
# Progress 453 / 3093 - effective seed 87 -SQL snippet can not be executed independently
# Progress 454 / 3093 - effective seed 87 -SQL snippet can not be executed independently
# Progress 455 / 3093 - effective seed 87 -SQL snippet can not be executed independently
# Progress 456 / 3093 - effective seed 87 -SQL snippet can not be executed independently
# Progress 457 / 3093 - effective seed 87 -SQL snippet can not be executed independently
# Progress 458 / 3093 - effective seed 87 -SQL snippet can not be executed independently
# Progress 459 / 3093 - effective seed 87 -SQL snippet can not be executed independently
# Progress 460 / 3093 - effective seed 87 -SQL snippet can not be executed independently
# Progress 461 / 3093 - effective seed 87 -SQL snippet can not be executed independently
# Progress 462 / 3093 - effective seed 87 -SQL snippet can not be executed independently
# Progress 463 / 3093 - effective seed 87 -SQL snippet can not be executed independently
# Progress 464 / 3093 - effective seed 87 -SQL snippet can not be executed independently
# Progress 465 / 3093 - effective seed 88 - SQL snippet can be executed independently
# Progress 466 / 3093 - effective seed 88 -SQL snippet can not be executed independently
# Progress 467 / 3093 - effective seed 88 -SQL snippet can not be executed independently
# Progress 468 / 3093 - effective seed 89 - SQL snippet can be executed independently
# Progress 469 / 3093 - effective seed 89 -SQL snippet can not be executed independently
# Progress 470 / 3093 - effective seed 90 - SQL snippet can be executed independently
# Progress 471 / 3093 - effective seed 90 -SQL snippet can not be executed independently
# Progress 472 / 3093 - effective seed 90 -SQL snippet can not be executed independently
# Progress 473 / 3093 - effective seed 90 -SQL snippet can not be executed independently
# Progress 474 / 3093 - effective seed 90 -SQL snippet can not be executed independently
# Progress 475 / 3093 - effective seed 91 - SQL snippet can be executed independently
# Progress 476 / 3093 - effective seed 91 -SQL snippet can not be executed independently
# Progress 477 / 3093 - effective seed 91 -SQL snippet can not be executed independently
# Progress 478 / 3093 - effective seed 91 -SQL snippet can not be executed independently
# Progress 479 / 3093 - effective seed 91 -SQL snippet can not be executed independently
# Progress 480 / 3093 - effective seed 91 -SQL snippet can not be executed independently
# Progress 481 / 3093 - effective seed 92 - SQL snippet can be executed independently
# Progress 482 / 3093 - effective seed 92 -SQL snippet can not be executed independently
# Progress 483 / 3093 - effective seed 92 -SQL snippet can not be executed independently
# Progress 484 / 3093 - effective seed 92 -SQL snippet can not be executed independently
# Progress 485 / 3093 - effective seed 92 -SQL snippet can not be executed independently
# Progress 486 / 3093 - effective seed 92 -SQL snippet can not be executed independently
# Progress 487 / 3093 - effective seed 92 -SQL snippet can not be executed independently
# Progress 488 / 3093 - effective seed 92 -SQL snippet can not be executed independently
# Progress 489 / 3093 - effective seed 92 -SQL snippet can not be executed independently
# Progress 490 / 3093 - effective seed 92 -SQL snippet can not be executed independently
# Progress 491 / 3093 - effective seed 92 -SQL snippet can not be executed independently
# Progress 492 / 3093 - effective seed 93 - SQL snippet can be executed independently
# Progress 493 / 3093 - effective seed 94 - SQL snippet can be executed independently
# Progress 494 / 3093 - effective seed 94 -SQL snippet can not be executed independently
# Progress 495 / 3093 - effective seed 94 -SQL snippet can not be executed independently
# Progress 496 / 3093 - effective seed 94 -SQL snippet can not be executed independently
# Progress 497 / 3093 - effective seed 94 -SQL snippet can not be executed independently
# Progress 498 / 3093 - effective seed 94 -SQL snippet can not be executed independently
# Progress 499 / 3093 - effective seed 95 - SQL snippet can be executed independently
# Progress 500 / 3093 - effective seed 95 -SQL snippet can not be executed independently
# Progress 501 / 3093 - effective seed 95 -SQL snippet can not be executed independently
# Progress 502 / 3093 - effective seed 95 -SQL snippet can not be executed independently
# Progress 503 / 3093 - effective seed 96 - SQL snippet can be executed independently
# Progress 504 / 3093 - effective seed 96 -SQL snippet can not be executed independently
# Progress 505 / 3093 - effective seed 96 -SQL snippet can not be executed independently
# Progress 506 / 3093 - effective seed 96 -SQL snippet can not be executed independently
# Progress 507 / 3093 - effective seed 96 -SQL snippet can not be executed independently
# Progress 508 / 3093 - effective seed 96 -SQL snippet can not be executed independently
# Progress 509 / 3093 - effective seed 96 -SQL snippet can not be executed independently
# Progress 510 / 3093 - effective seed 96 -SQL snippet can not be executed independently
# Progress 511 / 3093 - effective seed 96 -SQL snippet can not be executed independently
# Progress 512 / 3093 - effective seed 96 -SQL snippet can not be executed independently
# Progress 513 / 3093 - effective seed 97 - SQL snippet can be executed independently
# Progress 514 / 3093 - effective seed 97 -SQL snippet can not be executed independently
# Progress 515 / 3093 - effective seed 97 -SQL snippet can not be executed independently
# Progress 516 / 3093 - effective seed 97 -SQL snippet can not be executed independently
# Progress 517 / 3093 - effective seed 98 - SQL snippet can be executed independently
# Progress 518 / 3093 - effective seed 99 - SQL snippet can be executed independently
# Progress 519 / 3093 - effective seed 99 -SQL snippet can not be executed independently
# Progress 520 / 3093 - effective seed 99 -SQL snippet can not be executed independently
# Progress 521 / 3093 - effective seed 99 -SQL snippet can not be executed independently
# Progress 522 / 3093 - effective seed 99 -SQL snippet can not be executed independently
# Progress 523 / 3093 - effective seed 99 -SQL snippet can not be executed independently
# Progress 524 / 3093 - effective seed 99 -SQL snippet can not be executed independently
# Progress 525 / 3093 - effective seed 100 - SQL snippet can be executed independently
# Progress 526 / 3093 - effective seed 100 -SQL snippet can not be executed independently
# Progress 527 / 3093 - effective seed 100 -SQL snippet can not be executed independently
# Progress 528 / 3093 - effective seed 101 - SQL snippet can be executed independently
# Progress 529 / 3093 - effective seed 101 -SQL snippet can not be executed independently
# Progress 530 / 3093 - effective seed 101 -SQL snippet can not be executed independently
# Progress 531 / 3093 - effective seed 101 -SQL snippet can not be executed independently
# Progress 532 / 3093 - effective seed 101 -SQL snippet can not be executed independently
# Progress 533 / 3093 - effective seed 101 -SQL snippet can not be executed independently
# Progress 534 / 3093 - effective seed 101 -SQL snippet can not be executed independently
# Progress 535 / 3093 - effective seed 101 -SQL snippet can not be executed independently
# Progress 536 / 3093 - effective seed 101 -SQL snippet can not be executed independently
# Progress 537 / 3093 - effective seed 101 -SQL snippet can not be executed independently
# Progress 538 / 3093 - effective seed 101 -SQL snippet can not be executed independently
# Progress 539 / 3093 - effective seed 101 -SQL snippet can not be executed independently
# Progress 540 / 3093 - effective seed 101 -SQL snippet can not be executed independently
# Progress 541 / 3093 - effective seed 101 -SQL snippet can not be executed independently
# Progress 542 / 3093 - effective seed 101 -SQL snippet can not be executed independently
# Progress 543 / 3093 - effective seed 101 -SQL snippet can not be executed independently
# Progress 544 / 3093 - effective seed 101 -SQL snippet can not be executed independently
# Progress 545 / 3093 - effective seed 101 -SQL snippet can not be executed independently
# Progress 546 / 3093 - effective seed 101 -SQL snippet can not be executed independently
# Progress 547 / 3093 - effective seed 101 -SQL snippet can not be executed independently
# Progress 548 / 3093 - effective seed 101 -SQL snippet can not be executed independently
# Progress 549 / 3093 - effective seed 101 -SQL snippet can not be executed independently
# Progress 550 / 3093 - effective seed 101 -SQL snippet can not be executed independently
# Progress 551 / 3093 - effective seed 101 -SQL snippet can not be executed independently
# Progress 552 / 3093 - effective seed 101 -SQL snippet can not be executed independently
# Progress 553 / 3093 - effective seed 101 -SQL snippet can not be executed independently
# Progress 554 / 3093 - effective seed 101 -SQL snippet can not be executed independently
# ...
# Progress 2913 / 3093 - effective seed 483 -SQL snippet can not be executed independently
# Progress 2914 / 3093 - effective seed 483 -SQL snippet can not be executed independently
# Progress 2915 / 3093 - effective seed 483 -SQL snippet can not be executed independently
# Progress 2916 / 3093 - effective seed 483 -SQL snippet can not be executed independently
# Progress 2917 / 3093 - effective seed 483 -SQL snippet can not be executed independently
# Progress 2918 / 3093 - effective seed 483 -SQL snippet can not be executed independently
# Progress 2919 / 3093 - effective seed 483 -SQL snippet can not be executed independently
# Progress 2920 / 3093 - effective seed 484 - SQL snippet can be executed independently
# Progress 2921 / 3093 - effective seed 484 -SQL snippet can not be executed independently
# Progress 2922 / 3093 - effective seed 484 -SQL snippet can not be executed independently
# Progress 2923 / 3093 - effective seed 484 -SQL snippet can not be executed independently
# Progress 2924 / 3093 - effective seed 484 -SQL snippet can not be executed independently
# Progress 2925 / 3093 - effective seed 484 -SQL snippet can not be executed independently
# Progress 2926 / 3093 - effective seed 484 -SQL snippet can not be executed independently
# Progress 2927 / 3093 - effective seed 485 - SQL snippet can be executed independently
# Progress 2928 / 3093 - effective seed 485 -SQL snippet can not be executed independently
# Progress 2929 / 3093 - effective seed 485 -SQL snippet can not be executed independently
# Progress 2930 / 3093 - effective seed 486 - SQL snippet can be executed independently
# Progress 2931 / 3093 - effective seed 486 -SQL snippet can not be executed independently
# Progress 2932 / 3093 - effective seed 486 -SQL snippet can not be executed independently
# Progress 2933 / 3093 - effective seed 486 -SQL snippet can not be executed independently
# Progress 2934 / 3093 - effective seed 486 -SQL snippet can not be executed independently
# Progress 2935 / 3093 - effective seed 486 -SQL snippet can not be executed independently
# Progress 2936 / 3093 - effective seed 486 -SQL snippet can not be executed independently
# Progress 2937 / 3093 - effective seed 486 -SQL snippet can not be executed independently
# Progress 2938 / 3093 - effective seed 487 - SQL snippet can be executed independently
# Progress 2939 / 3093 - effective seed 487 -SQL snippet can not be executed independently
# Progress 2940 / 3093 - effective seed 487 -SQL snippet can not be executed independently
# Progress 2941 / 3093 - effective seed 487 -SQL snippet can not be executed independently
# Progress 2942 / 3093 - effective seed 487 -SQL snippet can not be executed independently
# Progress 2943 / 3093 - effective seed 487 -SQL snippet can not be executed independently
# Progress 2944 / 3093 - effective seed 487 -SQL snippet can not be executed independently
# Progress 2945 / 3093 - effective seed 487 -SQL snippet can not be executed independently
# Progress 2946 / 3093 - effective seed 487 -SQL snippet can not be executed independently
# Progress 2947 / 3093 - effective seed 487 -SQL snippet can not be executed independently
# Progress 2948 / 3093 - effective seed 487 -SQL snippet can not be executed independently
# Progress 2949 / 3093 - effective seed 487 -SQL snippet can not be executed independently
# Progress 2950 / 3093 - effective seed 488 - SQL snippet can be executed independently
# Progress 2951 / 3093 - effective seed 488 -SQL snippet can not be executed independently
# Progress 2952 / 3093 - effective seed 488 -SQL snippet can not be executed independently
# Progress 2953 / 3093 - effective seed 489 - SQL snippet can be executed independently
# Progress 2954 / 3093 - effective seed 489 -SQL snippet can not be executed independently
# Progress 2955 / 3093 - effective seed 489 -SQL snippet can not be executed independently
# Progress 2956 / 3093 - effective seed 489 -SQL snippet can not be executed independently
# Progress 2957 / 3093 - effective seed 489 -SQL snippet can not be executed independently
# Progress 2958 / 3093 - effective seed 490 - SQL snippet can be executed independently
# Progress 2959 / 3093 - effective seed 490 -SQL snippet can not be executed independently
# Progress 2960 / 3093 - effective seed 490 -SQL snippet can not be executed independently
# Progress 2961 / 3093 - effective seed 490 -SQL snippet can not be executed independently
# Progress 2962 / 3093 - effective seed 490 -SQL snippet can not be executed independently
# Progress 2963 / 3093 - effective seed 490 -SQL snippet can not be executed independently
# Progress 2964 / 3093 - effective seed 490 -SQL snippet can not be executed independently
# Progress 2965 / 3093 - effective seed 490 -SQL snippet can not be executed independently
# Progress 2966 / 3093 - effective seed 491 - SQL snippet can be executed independently
# Progress 2967 / 3093 - effective seed 491 -SQL snippet can not be executed independently
# Progress 2968 / 3093 - effective seed 492 - SQL snippet can be executed independently
# Progress 2969 / 3093 - effective seed 493 - SQL snippet can be executed independently
# Progress 2970 / 3093 - effective seed 493 -SQL snippet can not be executed independently
# Progress 2971 / 3093 - effective seed 493 -SQL snippet can not be executed independently
# Progress 2972 / 3093 - effective seed 494 - SQL snippet can be executed independently
# Progress 2973 / 3093 - effective seed 494 -SQL snippet can not be executed independently
# Progress 2974 / 3093 - effective seed 494 -SQL snippet can not be executed independently
# Progress 2975 / 3093 - effective seed 495 - SQL snippet can be executed independently
# Progress 2976 / 3093 - effective seed 495 -SQL snippet can not be executed independently
# Progress 2977 / 3093 - effective seed 495 -SQL snippet can not be executed independently
# Progress 2978 / 3093 - effective seed 495 -SQL snippet can not be executed independently
# Progress 2979 / 3093 - effective seed 495 -SQL snippet can not be executed independently
# Progress 2980 / 3093 - effective seed 495 -SQL snippet can not be executed independently
# Progress 2981 / 3093 - effective seed 496 - SQL snippet can be executed independently
# Progress 2982 / 3093 - effective seed 496 -SQL snippet can not be executed independently
# Progress 2983 / 3093 - effective seed 496 -SQL snippet can not be executed independently
# Progress 2984 / 3093 - effective seed 496 -SQL snippet can not be executed independently
# Progress 2985 / 3093 - effective seed 496 -SQL snippet can not be executed independently
# Progress 2986 / 3093 - effective seed 496 -SQL snippet can not be executed independently
# Progress 2987 / 3093 - effective seed 496 -SQL snippet can not be executed independently
# Progress 2988 / 3093 - effective seed 496 -SQL snippet can not be executed independently
# Progress 2989 / 3093 - effective seed 496 -SQL snippet can not be executed independently
# Progress 2990 / 3093 - effective seed 496 -SQL snippet can not be executed independently
# Progress 2991 / 3093 - effective seed 496 -SQL snippet can not be executed independently
# Progress 2992 / 3093 - effective seed 496 -SQL snippet can not be executed independently
# Progress 2993 / 3093 - effective seed 496 -SQL snippet can not be executed independently
# Progress 2994 / 3093 - effective seed 496 -SQL snippet can not be executed independently
# Progress 2995 / 3093 - effective seed 496 -SQL snippet can not be executed independently
# Progress 2996 / 3093 - effective seed 496 -SQL snippet can not be executed independently
# Progress 2997 / 3093 - effective seed 496 -SQL snippet can not be executed independently
# Progress 2998 / 3093 - effective seed 496 -SQL snippet can not be executed independently
# Progress 2999 / 3093 - effective seed 496 -SQL snippet can not be executed independently
# Progress 3000 / 3093 - effective seed 496 -SQL snippet can not be executed independently
# Progress 3001 / 3093 - effective seed 496 -SQL snippet can not be executed independently
# Progress 3002 / 3093 - effective seed 496 -SQL snippet can not be executed independently
# Progress 3003 / 3093 - effective seed 496 -SQL snippet can not be executed independently
# Progress 3004 / 3093 - effective seed 496 -SQL snippet can not be executed independently
# Progress 3005 / 3093 - effective seed 496 -SQL snippet can not be executed independently
# Progress 3006 / 3093 - effective seed 496 -SQL snippet can not be executed independently
# Progress 3007 / 3093 - effective seed 496 -SQL snippet can not be executed independently
# Progress 3008 / 3093 - effective seed 496 -SQL snippet can not be executed independently
# Progress 3009 / 3093 - effective seed 496 -SQL snippet can not be executed independently
# Progress 3010 / 3093 - effective seed 496 -SQL snippet can not be executed independently
# Progress 3011 / 3093 - effective seed 496 -SQL snippet can not be executed independently
# Progress 3012 / 3093 - effective seed 496 -SQL snippet can not be executed independently
# Progress 3013 / 3093 - effective seed 496 -SQL snippet can not be executed independently
# Progress 3014 / 3093 - effective seed 496 -SQL snippet can not be executed independently
# Progress 3015 / 3093 - effective seed 496 -SQL snippet can not be executed independently
# Progress 3016 / 3093 - effective seed 497 - SQL snippet can be executed independently
# Progress 3017 / 3093 - effective seed 497 -SQL snippet can not be executed independently
# Progress 3018 / 3093 - effective seed 497 -SQL snippet can not be executed independently
# Progress 3019 / 3093 - effective seed 497 -SQL snippet can not be executed independently
# Progress 3020 / 3093 - effective seed 497 -SQL snippet can not be executed independently
# Progress 3021 / 3093 - effective seed 497 -SQL snippet can not be executed independently
# Progress 3022 / 3093 - effective seed 497 -SQL snippet can not be executed independently
# Progress 3023 / 3093 - effective seed 497 -SQL snippet can not be executed independently
# Progress 3024 / 3093 - effective seed 498 - SQL snippet can be executed independently
# Progress 3025 / 3093 - effective seed 498 -SQL snippet can not be executed independently
# Progress 3026 / 3093 - effective seed 498 -SQL snippet can not be executed independently
# Progress 3027 / 3093 - effective seed 498 -SQL snippet can not be executed independently
# Progress 3028 / 3093 - effective seed 498 -SQL snippet can not be executed independently
# Progress 3029 / 3093 - effective seed 498 -SQL snippet can not be executed independently
# Progress 3030 / 3093 - effective seed 498 -SQL snippet can not be executed independently
# Progress 3031 / 3093 - effective seed 498 -SQL snippet can not be executed independently
# Progress 3032 / 3093 - effective seed 498 -SQL snippet can not be executed independently
# Progress 3033 / 3093 - effective seed 498 -SQL snippet can not be executed independently
# Progress 3034 / 3093 - effective seed 498 -SQL snippet can not be executed independently
# Progress 3035 / 3093 - effective seed 498 -SQL snippet can not be executed independently
# Progress 3036 / 3093 - effective seed 498 -SQL snippet can not be executed independently
# Progress 3037 / 3093 - effective seed 498 -SQL snippet can not be executed independently
# Progress 3038 / 3093 - effective seed 498 -SQL snippet can not be executed independently
# Progress 3039 / 3093 - effective seed 498 -SQL snippet can not be executed independently
# Progress 3040 / 3093 - effective seed 498 -SQL snippet can not be executed independently
# Progress 3041 / 3093 - effective seed 498 -SQL snippet can not be executed independently
# Progress 3042 / 3093 - effective seed 498 -SQL snippet can not be executed independently
# Progress 3043 / 3093 - effective seed 499 - SQL snippet can be executed independently
# Progress 3044 / 3093 - effective seed 500 - SQL snippet can be executed independently
# Progress 3045 / 3093 - effective seed 500 -SQL snippet can not be executed independently
# Progress 3046 / 3093 - effective seed 500 -SQL snippet can not be executed independently
# Progress 3047 / 3093 - effective seed 500 -SQL snippet can not be executed independently
# Progress 3048 / 3093 - effective seed 500 -SQL snippet can not be executed independently
# Progress 3049 / 3093 - effective seed 500 -SQL snippet can not be executed independently
# Progress 3050 / 3093 - effective seed 500 -SQL snippet can not be executed independently
# Progress 3051 / 3093 - effective seed 501 - SQL snippet can be executed independently
# Progress 3052 / 3093 - effective seed 501 -SQL snippet can not be executed independently
# Progress 3053 / 3093 - effective seed 501 -SQL snippet can not be executed independently
# Progress 3054 / 3093 - effective seed 501 -SQL snippet can not be executed independently
# Progress 3055 / 3093 - effective seed 501 -SQL snippet can not be executed independently
# Progress 3056 / 3093 - effective seed 501 -SQL snippet can not be executed independently
# Progress 3057 / 3093 - effective seed 501 -SQL snippet can not be executed independently
# Progress 3058 / 3093 - effective seed 502 - SQL snippet can be executed independently
# Progress 3059 / 3093 - effective seed 502 -SQL snippet can not be executed independently
# Progress 3060 / 3093 - effective seed 503 - SQL snippet can be executed independently
# Progress 3061 / 3093 - effective seed 503 -SQL snippet can not be executed independently
# Progress 3062 / 3093 - effective seed 503 -SQL snippet can not be executed independently
# Progress 3063 / 3093 - effective seed 503 -SQL snippet can not be executed independently
# Progress 3064 / 3093 - effective seed 503 -SQL snippet can not be executed independently
# Progress 3065 / 3093 - effective seed 503 -SQL snippet can not be executed independently
# Progress 3066 / 3093 - effective seed 503 -SQL snippet can not be executed independently
# Progress 3067 / 3093 - effective seed 503 -SQL snippet can not be executed independently
# Progress 3068 / 3093 - effective seed 503 -SQL snippet can not be executed independently
# Progress 3069 / 3093 - effective seed 503 -SQL snippet can not be executed independently
# Progress 3070 / 3093 - effective seed 503 -SQL snippet can not be executed independently
# Progress 3071 / 3093 - effective seed 503 -SQL snippet can not be executed independently
# Progress 3072 / 3093 - effective seed 503 -SQL snippet can not be executed independently
# Progress 3073 / 3093 - effective seed 503 -SQL snippet can not be executed independently
# Progress 3074 / 3093 - effective seed 503 -SQL snippet can not be executed independently
# Progress 3075 / 3093 - effective seed 503 -SQL snippet can not be executed independently
# Progress 3076 / 3093 - effective seed 503 -SQL snippet can not be executed independently
# Progress 3077 / 3093 - effective seed 503 -SQL snippet can not be executed independently
# Progress 3078 / 3093 - effective seed 503 -SQL snippet can not be executed independently
# Progress 3079 / 3093 - effective seed 503 -SQL snippet can not be executed independently
# Progress 3080 / 3093 - effective seed 503 -SQL snippet can not be executed independently
# Progress 3081 / 3093 - effective seed 503 -SQL snippet can not be executed independently
# Progress 3082 / 3093 - effective seed 503 -SQL snippet can not be executed independently
# Progress 3083 / 3093 - effective seed 503 -SQL snippet can not be executed independently
# Progress 3084 / 3093 - effective seed 503 -SQL snippet can not be executed independently
# Progress 3085 / 3093 - effective seed 503 -SQL snippet can not be executed independently
# Progress 3086 / 3093 - effective seed 503 -SQL snippet can not be executed independently
# Progress 3087 / 3093 - effective seed 503 -SQL snippet can not be executed independently
# Progress 3088 / 3093 - effective seed 503 -SQL snippet can not be executed independently
# Progress 3089 / 3093 - effective seed 504 - SQL snippet can be executed independently
# Progress 3090 / 3093 - effective seed 505 - SQL snippet can be executed independently
# Progress 3091 / 3093 - effective seed 505 -SQL snippet can not be executed independently
# Progress 3092 / 3093 - effective seed 505 -SQL snippet can not be executed independently

# %%
# save seed_sql_snippets as text file
path = './seeds'

for idx, sql_snippet in enumerate(seed_sql_snippets):
    file_name = f'{path}/{idx}.sql'
    with open(file_name, 'w', encoding='utf-8') as f:
        f.write(sql_snippet)
        f.write('\n')
        
print(f"Save {len(seed_sql_snippets)} seed sql snippets to {path}")
# Out:
# Save 505 seed sql snippets to ./seeds
